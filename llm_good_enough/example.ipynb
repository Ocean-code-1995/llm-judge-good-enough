# %% [markdown]
# ### ***`Example Usage`***
# ---

# %% [markdown]
# #### ***Read Data***

# %%
import pandas as pd

df = pd.read_csv('../wmt-human/data/wmt-clean.csv')
print(df.shape)
df.head()
# Out:
# (8135, 6)
#    human_#1  human_#2  human_#3  GPT_as_a_judge  MISTRAL_as_a_judge  \
# 0         4         2         4               6                   6
# 1         4         5         4               6                   6
# 2         5         5         4               6                   6
# 3         4         4         4               6                   6
# 4         4         0         4               6                   6
#
#    LLAMA_as_a_judge
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4

# %%
from evaluator import LLMGoodEnough

# define human judge columns
human_cols = [col for col in df.columns if col.startswith('human_')]

# initialize evaluator instance
LLM_Evaluator = LLMGoodEnough(df=df, human_cols=human_cols)

# visualize LLM-as-a-judge good enough
LLM_Evaluator.visulize_good_enough(
    llm_col='LLAMA_as_a_judge',        # LLM-as-a-judge column name
    min_score=0,                       # minimum judge score
    max_score=6,                       # maximum judge score
    y_lim=0.6,                         # y-axis limit -> probability (0-1)
)
# Out:
# /Users/sebastianwefers/Desktop/LLM-as-a-Judge/LLM-as-a-Judge-good-enough/llm_good_enough/evaluator.py:227: UserWarning: Mismatched number of handles and labels: len(handles) = 3 len(labels) = 2
#   legend = ax.legend(
