# %% [markdown]
# # PolitiFact — Analysis (index)
#
# This benchmark has two analysis notebooks:
# - `analysis_s3.ipynb` — 3-point scale
# - `analysis_s6.ipynb` — 6-point scale
#
# Data preprocessing is done in `preprocessing.ipynb`.
